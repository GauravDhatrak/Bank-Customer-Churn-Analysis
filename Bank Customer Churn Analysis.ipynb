# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython import get_ipython
import warnings
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv("Bank Customer Churn.csv")

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.nunique()
# Out:
# RowNumber          10000
# CustomerId         10000
# Surname             2932
# CreditScore          460
# Geography              3
# Gender                 2
# Age                   70
# Tenure                11
# Balance             6382
# NumOfProducts          4
# HasCrCard              2
# IsActiveMember         2
# EstimatedSalary     9999
# Exited                 2
# dtype: int64

# %%
data_new = data.drop(['RowNumber', 'CustomerId', 'Surname'], axis = 1)

# %%
data_new.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# # Exploratory Data Analysis

# %%
data_new['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
data_new['Geography'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='Geography', data=data_new, palette='hls')

plt.xlabel("Geography", size = 20, color = "black")
plt.ylabel("Count", size = 20, color = "black")
plt.title("Count of Records by Geography", size=22, color="black")
plt.xticks(fontsize=14, rotation=0)
plt.yticks(fontsize = 14, rotation = 0)

plt.show()

# %%
data_new['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
data_new['Gender'].value_counts()
# Out:
# Male      5457
# Female    4543
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(x = 'Gender', data = data_new)

plt.xlabel("Gender", size = 20, color = "black")
plt.ylabel("Count", size = 20, color = "black")
plt.title("Count of Records by Gender", size=22, color="black")
plt.xticks(fontsize=14, rotation=0)
plt.yticks(fontsize = 14, rotation = 0)
sns.set_palette('viridis')


plt.show()

# %%
data_new['NumOfProducts'].unique()
# Out:
# array([1, 3, 2, 4], dtype=int64)

# %%
data_new['NumOfProducts'].value_counts()
# Out:
# 1    5084
# 2    4590
# 3     266
# 4      60
# Name: NumOfProducts, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(x = 'NumOfProducts', data = data_new)

plt.xlabel("Nuber_OF_Product", size = 20, color = "black")
plt.ylabel("Count", size = 20, color = "black")
plt.title("Count of Records by Number_Of_Products", size=22, color="black")
plt.xticks(fontsize=14, rotation=0)
plt.yticks(fontsize = 14, rotation = 0)
sns.set_palette('magma')

plt.show()

# %%
data_new['HasCrCard'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data_new['HasCrCard'].value_counts()
# Out:
# 1    7055
# 0    2945
# Name: HasCrCard, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.set_palette('magma')

sns.countplot(x = 'HasCrCard', data = data_new, palette='Greens')

plt.xlabel("HasCrCard", size = 20, color = "black")
plt.ylabel("Count", size = 20, color = "black")
plt.title("Count of Records by HasCrCard", size=22, color="black")
plt.xticks(fontsize=14, rotation=0)
plt.yticks(fontsize = 14, rotation = 0)
sns.set_palette('magma')


plt.show()

# %%
data_new['IsActiveMember'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data_new['IsActiveMember'].value_counts()
# Out:
# 1    5151
# 0    4849
# Name: IsActiveMember, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x = 'IsActiveMember', data = data_new, palette='hls')

plt.xlabel("IsActiveMember", size = 20, color = "black")
plt.ylabel("Count", size = 20, color = "black")
plt.title("Count of Records by IsActiveMember", size=22, color="black")
plt.xticks(fontsize=14, rotation=0)
plt.yticks(fontsize = 14, rotation = 0)
sns.set_palette('plasma')


plt.show()

# %%
data_new['Exited'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data_new['Exited'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(x = 'Exited', data = data_new)

plt.xlabel("Exited", size = 20, color = "black")
plt.ylabel("Count", size = 20, color = "black")
plt.title("Count of Records by Exited", size=22, color="black")
plt.xticks(fontsize=14, rotation=0)
plt.yticks(fontsize = 14, rotation = 0)
sns.set_palette('viridis')


plt.show()

# %%
plt.figure(figsize=(15,6))
colors = sns.color_palette('muted')
explode = [0.3, 0.02]
plt.pie(data_new['Exited'].value_counts(), colors = ['Red', 'orange'],
labels = ['Retained', 'Exited'],
explode = [0.2,0.01], autopct = '%0.0f%%', shadow = 'True',
startangle = 90)
plt.show()

# %%
data_new.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %%
data_new_numeric = data_new[['CreditScore', 'Age', 'Tenure', 'Balance',
'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
'Exited']]

# %%
for i in data_new_numeric.columns:
    plt.figure(figsize=(15,6))
    sns.boxplot(x = data_new_numeric[i], data = data_new_numeric)
    
    plt.xlabel(i, size=18)    
    
    plt.show()

# %%
for i in data_new_numeric.columns:
    plt.figure(figsize=(15,6))
    sns.distplot(data_new_numeric[i], color='green')
    
    plt.xlabel(i, size=18)  
    plt.ylabel(" Density", size=18) 
    
    plt.tight_layout()

# %%
data_exited = data_new.drop(columns = 'Exited')
data_exited.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary'],
#       dtype='object')

# %%
data_exited.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
for i in data_exited[['Geography', 'Gender', 'Age', 'Tenure',
'NumOfProducts', 'HasCrCard', 'IsActiveMember']]:
    plt.figure(figsize=(15,6))
    sns.countplot(x = data_exited[i], hue = 'Exited' , data = data_new_numeric)
    
    plt.show()

# %%
for i in data_exited[['Geography', 'Gender', 'Age', 'Tenure',
'NumOfProducts', 'HasCrCard', 'IsActiveMember']]:
    plt.figure(figsize=(15,6))
    sns.histplot(data_new_numeric, x = data_exited[i], hue = 'Exited', palette='plasma')
  
    plt.show()

# %%
data_new_numeric.corr()
# Out:
#                  CreditScore       Age    Tenure   Balance  NumOfProducts  \
# CreditScore         1.000000 -0.003965  0.000842  0.006268       0.012238
# Age                -0.003965  1.000000 -0.009997  0.028308      -0.030680
# Tenure              0.000842 -0.009997  1.000000 -0.012254       0.013444
# Balance             0.006268  0.028308 -0.012254  1.000000      -0.304180
# NumOfProducts       0.012238 -0.030680  0.013444 -0.304180       1.000000
# HasCrCard          -0.005458 -0.011721  0.022583 -0.014858       0.003183
# IsActiveMember      0.025651  0.085472 -0.028362 -0.010084       0.009612
# EstimatedSalary    -0.001384 -0.007201  0.007784  0.012797       0.014204
# Exited             -0.027094  0.285323 -0.014001  0.118533      -0.047820
#
#                  HasCrCard  IsActiveMember  EstimatedSalary    Exited
# CreditScore      -0.005458        0.025651        -0.001384 -0.027094
# Age              -0.011721        0.085472        -0.007201  0.285323
# ...

# %%
plt.figure(figsize=(15,6))
sns.heatmap(data_new_numeric.corr(), annot = True)
plt.show()

# %%
data_new['age_groups'] = pd.cut(data_new['Age'], bins=6)

# %%
data_new_age = data_new.copy()

# %%
data_new_age = data_new_age.groupby(['age_groups','Exited']).agg({'Gender' : 'count'}).reset_index()
data_new_age.columns = ['age_groups','Exited','user_count']
data_new_age['Exited'] = data_new_age['Exited'].apply(lambda x : 'Exited' if x == 1 else 'Retained')

# %%
data_new_age
# Out:
#           age_groups    Exited  user_count
# 0   (17.926, 30.333]  Retained        1820
# 1   (17.926, 30.333]    Exited         148
# 2   (30.333, 42.667]  Retained        4454
# 3   (30.333, 42.667]    Exited         684
# 4     (42.667, 55.0]  Retained        1183
# 5     (42.667, 55.0]    Exited         911
# 6     (55.0, 67.333]  Retained         337
# 7     (55.0, 67.333]    Exited         271
# 8   (67.333, 79.667]  Retained         155
# 9   (67.333, 79.667]    Exited          22
# 10    (79.667, 92.0]  Retained          14
# 11    (79.667, 92.0]    Exited           1

# %%
plt.figure(figsize=(12,8))
sns.barplot(data = data_new_age, x = 'age_groups', y = 'user_count',hue = 'Exited', palette='plasma')
plt.ylabel('Total User')
plt.show()

# %%
data_new_geo = data_new.groupby(['Geography','Exited']).agg({'Gender':'count'}).reset_index()
data_new_geo.columns = ['Geography','Exited','user_count']
data_new_geo
# Out:
#   Geography  Exited  user_count
# 0    France       0        4204
# 1    France       1         810
# 2   Germany       0        1695
# 3   Germany       1         814
# 4     Spain       0        2064
# 5     Spain       1         413

# %%
plt.figure(figsize=(12,8))
sns.barplot(data = data_new_geo, x = 'Geography',y='user_count',hue='Exited',palette = 'viridis')
plt.show()

# %%
data_new_product = data_new.groupby(['NumOfProducts','Exited']).agg({'Gender' : 'count'}).reset_index()
data_new_product.columns = ['NumOfProducts','Exited','user_count']
data_new_product
# Out:
#    NumOfProducts  Exited  user_count
# 0              1       0        3675
# 1              1       1        1409
# 2              2       0        4242
# 3              2       1         348
# 4              3       0          46
# 5              3       1         220
# 6              4       1          60

# %%
plt.figure(figsize=(12,8))
sns.barplot(data = data_new_product, x = 'NumOfProducts',y='user_count', hue='Exited',palette = 'magma')
plt.show()

# %%
data_new['CreditScoreNew'] = pd.cut(data_new['CreditScore'], bins=6)

data_new_creditscore = data_new.groupby(['CreditScoreNew','Exited']).agg({'Gender' : 'count'}).reset_index()
data_new_creditscore.columns = ['CreditScoreNew','Exited','user_count']
data_new_creditscore
# Out:
#         CreditScoreNew  Exited  user_count
# 0     (349.5, 433.333]       0          67
# 1     (349.5, 433.333]       1          40
# 2   (433.333, 516.667]       0         640
# 3   (433.333, 516.667]       1         162
# 4     (516.667, 600.0]       0        1694
# 5     (516.667, 600.0]       1         463
# 6     (600.0, 683.333]       0        2560
# 7     (600.0, 683.333]       1         633
# 8   (683.333, 766.667]       0        2013
# 9   (683.333, 766.667]       1         496
# 10    (766.667, 850.0]       0         989
# 11    (766.667, 850.0]       1         243

# %%
plt.figure(figsize=(12,8))
sns.barplot(data = data_new_creditscore, x = 'CreditScoreNew',y='user_count', hue='Exited', palette='plasma')

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)


plt.show()
